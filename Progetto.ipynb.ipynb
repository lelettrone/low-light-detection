# %%
# !pip uninstall -y keras-nightly Keras
# !pip install keras-resnet==0.2.0 
# !pip install tensorflow==2.3.0 
# !pip install keras==2.4.3 
# !pip install keras-application

# %%
# %reset -sf
# !rm -dr ./keras-retinanet/
# !rm -dr ./snapshots/

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git

# %%
# %cd keras-retinanet/

# !pip install .

# %%
# !python setup.py build_ext --inplace

# %%
# %cd ./..
# Out:
# /content

# %%
# !python /content/keras-retinanet/keras_retinanet/bin/train.py  --backbone resnet50 --freeze-backbone --batch-size 6 --steps 334 --lr 1e-4 --epochs 15 --compute-val-loss csv /content/drive/MyDrive/csv_traning.csv /content/drive/MyDrive/csv_class.csv --val-annotations /content/drive/MyDrive/csv_validation.csv
# Out:
# 2021-06-10 15:42:06.851661: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Creating model, this may take a second...
# 2021-06-10 15:42:11.236936: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-10 15:42:11.269455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-10 15:42:11.270034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-10 15:42:11.270077: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python /content/keras-retinanet/keras_retinanet/bin/convert_model.py /content/snapshots/resnet50_csv_16.h5 /content/inferec/xx.h5
# Out:
# 2021-06-09 18:08:39.792746: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-09 18:08:41.031033: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-09 18:08:41.065228: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 18:08:41.065846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-09 18:08:41.065881: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python /content/keras-retinanet/keras_retinanet/bin/evaluate.py csv /content/drive/MyDrive/csv_test.csv /content/drive/MyDrive/csv_class.csv /content/inferec/xx.h5
# Out:
# 2021-06-04 16:57:35.127473: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loading model, this may take a second...
# 2021-06-04 16:57:42.172547: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-04 16:57:42.195425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-04 16:57:42.196292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-06-04 16:57:42.196344: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %matplotlib inline
# !python /content/keras-retinanet/examples/resnet50_retinanet.py
# Out:
# 2021-06-09 18:26:17.980916: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-09 18:26:19.405118: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-09 18:26:19.437488: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-09 18:26:19.438084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-09 18:26:19.438155: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...
